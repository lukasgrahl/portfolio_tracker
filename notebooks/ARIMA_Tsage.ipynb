# %%
# %run init_notebookspace.py
# Out:
# DATA_DIR is existant under: /Users/tsagedouglas/Data Science Project (Python Proj)/data

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (0.2.12)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=1.3.0 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (1.5.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: html5lib>=1.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: pytz>=2022.5 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (2022.6)
# Requirement already satisfied: lxml>=4.9.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (38.0.4)
# Requirement already satisfied: requests>=2.26 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: pycparser in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
# !pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas_datareader) (2.28.1)
# Requirement already satisfied: pandas>=0.23 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas_datareader) (1.5.2)
# Requirement already satisfied: lxml in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas_datareader) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (2022.6)
# Requirement already satisfied: numpy>=1.20.3 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (1.23.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (2.1.1)
# Requirement already satisfied: six>=1.5 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)

# %%
# !pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (0.8.9.1)
# Requirement already satisfied: feedparser in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: requests-html in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: requests in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yahoo_fin) (2.28.1)
# Requirement already satisfied: pandas in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from yahoo_fin) (1.5.2)
# Requirement already satisfied: sgmllib3k in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas->yahoo_fin) (2022.6)
# Requirement already satisfied: numpy>=1.20.3 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas->yahoo_fin) (1.23.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests->yahoo_fin) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests->yahoo_fin) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests->yahoo_fin) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests->yahoo_fin) (2.1.1)
# Requirement already satisfied: parse in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: fake-useragent in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests-html->yahoo_fin) (1.1.1)
# Requirement already satisfied: pyquery in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: w3lib in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests-html->yahoo_fin) (2.1.1)
# Requirement already satisfied: bs4 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.65.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (5.1.0)
# Requirement already satisfied: six>=1.5 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from bs4->requests-html->yahoo_fin) (4.11.1)
# Requirement already satisfied: importlib-resources>=5.0 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from fake-useragent->requests-html->yahoo_fin) (5.10.0)
# Requirement already satisfied: cssselect>=1.2.0 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pyquery->requests-html->yahoo_fin) (1.2.0)
# Requirement already satisfied: lxml>=2.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pyquery->requests-html->yahoo_fin) (4.9.1)
# Requirement already satisfied: zipp>=0.5 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.11.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.3.2.post1)

# %%
import pandas as pd
import numpy as np

import yfinance as yf
import pandas_datareader as pdread
from pandas_datareader import fred

import matplotlib.pyplot as plt

from statsmodels.tsa.arima.model import ARIMA
from yahoo_fin import stock_info as ysi

from itertools import chain

# %%
from src.utils import apply_datetime_format

# %%
# get sp500 composits & market cap
sp500_tickers = ysi.tickers_sp500()
df = pd.DataFrame(index=sp500_tickers, 
                  columns=['market_cap'], 
                  data=[pdread.get_quote_yahoo(item)['marketCap'].values[0] for item in sp500_tickers])
sp500_largest = df.sort_values('market_cap', ascending=False).index[:5].values
sp500_ticker = ['^GSPC']

# %%
start = '2020-01-01'
end = '2022-12-31'

# %%
df_prices = pd.DataFrame()
df_prices.index = pd.date_range(start, periods=(apply_datetime_format(end, '%Y-%m-%d') - apply_datetime_format(start, '%Y-%m-%d')).days)

for item in [*chain(sp500_largest, sp500_ticker)]:
    data = yf.download(item, start, end)
    data.columns = list([f'{item}_{x}' for x in data.columns])
    df_prices = df_prices.join(data)
    
# get closing price
df_c = df_prices[[item for item in df_prices.columns if 'Adj Close' in item]].copy()
df_c.columns = [item[:-10] for item in df_c.columns]
df_c.dropna(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# get log returns
df_rets = np.log(df_c / df_c.shift(1)).dropna()
df_rets.sort_index(inplace=True)
df_rets.asfreq = "D"

df_rets['^GSPC_lead'] = df_rets['^GSPC'].shift(1)

df_rets.dropna(inplace=True)
df_rets.index.asfreq = 'd'

# %%
# save data to file
df_rets.to_csv(os.path.join(DATA_DIR, 'returns.csv'))

# %%
# load data from file
df_rets = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'))

# %%
# Checking for stationarity via ADF test below
# dickey-fuller attempt 1 
from statsmodels.tsa.stattools import adfuller  
from numpy import log  
import pandas as pd  
  
mydata = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)  

res = adfuller(mydata.value.dropna())  
                     
print('Augmented Dickey-Fuller Statistic: %f' % res[0])  
print('p-value: %f' % res[1])
# Out:
# Augmented Dickey-Fuller Statistic: -8.078260
# p-value: 0.000000

# %%
# determining the ADF for the 'd' value of ARIMA

# %%
# Next looking at autocorrelation 
import numpy as np, pandas as pd  
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf  
import matplotlib.pyplot as plt 
plt.rcParams.update({'figure.figsize' : (9,7), 'figure.dpi' : 120})
plt.show()

# %%
# Importing data  
df = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)

# %%
#print (df)

# %%
# The Genuine Series 
fig, axes = plt.subplots(3, 2, sharex = True)  
axes[0, 0].plot(df.value); axes[0, 0].set_title('The Genuine Series')  
plot_acf(df.value, ax = axes[0, 1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # The Genuine Series
#       2 fig, axes = plt.subplots(3, 2, sharex = True)
# ----> 3 axes[0, 0].plot(df.value); axes[0, 0].set_title('The Genuine Series')
#       4 plot_acf(df.value, ax = axes[0, 1])
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     x, y = index_of(xy[-1])
#     498 if self.axes.xaxis is not None:
# --> 499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
#     501     self.axes.yaxis.update_units(y)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axis.py:1608, in Axis.update_units(self, data)
#    1606 neednew = self.converter != converter
#    1607 self.converter = converter
# -> 1608 default = self.converter.default_units(data, self)
#    1609 if default is not None and self.units is None:
#    1610     self.set_units(default)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:227, in UnitData.update(self, data)
#     224 convertible = True
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#     230         convertible = self._str_is_convertible(val)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a tuple

# %%
# Order of Differencing: First  
axes[1, 0].plot(mydata.value.diff()); axes[1, 0].set_title('Order of Differencing: First')  
plot_acf(df.value.diff().dropna(), ax = axes[1, 1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Order of Differencing: First
# ----> 2 axes[1, 0].plot(mydata.value.diff()); axes[1, 0].set_title('Order of Differencing: First')
#       3 plot_acf(df.value.diff().dropna(), ax = axes[1, 1])
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     x, y = index_of(xy[-1])
#     498 if self.axes.xaxis is not None:
# --> 499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
#     501     self.axes.yaxis.update_units(y)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axis.py:1608, in Axis.update_units(self, data)
#    1606 neednew = self.converter != converter
#    1607 self.converter = converter
# -> 1608 default = self.converter.default_units(data, self)
#    1609 if default is not None and self.units is None:
#    1610     self.set_units(default)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:227, in UnitData.update(self, data)
#     224 convertible = True
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#     230         convertible = self._str_is_convertible(val)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a tuple

# %%
# Order of Differencing: Second  
axes[2, 0].plot(df.value.diff().diff()); axes[2, 0].set_title('Order of Differencing: Second')  
plot_acf(df.value.diff().diff().dropna(), ax = axes[2, 1])  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Order of Differencing: Second
# ----> 2 axes[2, 0].plot(df.value.diff().diff()); axes[2, 0].set_title('Order of Differencing: Second')
#       3 plot_acf(df.value.diff().diff().dropna(), ax = axes[2, 1])
#       4 plt.show()
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     x, y = index_of(xy[-1])
#     498 if self.axes.xaxis is not None:
# --> 499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
#     501     self.axes.yaxis.update_units(y)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/axis.py:1608, in Axis.update_units(self, data)
#    1606 neednew = self.converter != converter
#    1607 self.converter = converter
# -> 1608 default = self.converter.default_units(data, self)
#    1609 if default is not None and self.units is None:
#    1610     self.set_units(default)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/category.py:227, in UnitData.update(self, data)
#     224 convertible = True
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#     230         convertible = self._str_is_convertible(val)
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a tuple

# %%
# Determine the differencing above. Weak/ strong stationarity? 
# Next, looking at how to make the data stationary via 3 tests.

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (2.0.3)
# Requirement already satisfied: pandas>=0.19 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (65.5.1)
# Requirement already satisfied: numpy>=1.21.2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (1.9.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: joblib>=0.11 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: urllib3 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (1.26.13)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2022.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
from pmdarima.arima.utils import ndiffs  
import pandas as pd
import os

# %%
df = pd.read_csv(pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)
X = df.value
# Out:
#   Cell In[26], line 2
#     X = df.value
#     ^
# SyntaxError: invalid syntax

# %%
# Augmented Dickey Fuller Test  
adftest = ndiffs(df, test = 'adf')

# %%
# KPSS Test  
kpsstest = ndiffs(df, test = 'kpss')

# %%
# PP Test  
pptest = ndiffs(df, test = 'pp')

# %%
print("ADF Test =", adftest)  
print("KPSS Test =", kpsstest)  
print("PP Test =", pptest)
# Out:
# ADF Test = 0
# KPSS Test = 0
# PP Test = 0

# %%
#Next finding the 'p' term for AR via a partial auocorrelation graph

# %%
import numpy as np, pandas as pd  
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf  
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

# %%
import os

# %%
# importing data 
df = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)

# %%
 plt.plot(df.to_numpy(), label='Close')

# %%
ndarray = np.asarray(df)
print(ndarray)
# Out:
# [[-7.08490936e-03]
#  [ 3.52714519e-03]
#  [-2.80717508e-03]
#  [ 4.89047349e-03]
#  [ 6.63321412e-03]
#  [-2.85926249e-03]
#  [ 6.95199405e-03]
#  [-1.51568084e-03]
#  [ 1.86845024e-03]
#  [ 8.33174742e-03]
#  [ 3.85472325e-03]
#  [-2.65550037e-03]
#  [ 2.89034297e-04]
#  [ 1.14032619e-03]
#  [-9.08328943e-03]
#  [-1.58557524e-02]
#  [ 1.00033835e-02]
#  [-8.67250144e-04]
#  [ 3.12945693e-03]
#  [-1.78644436e-02]
#  [ 7.22842576e-03]
#  [ 1.48693159e-02]
#  [ 1.11877787e-02]
#  [ 3.32015506e-03]
#  [-5.41549101e-03]
#  [ 7.29969012e-03]
#  [ 1.68704869e-03]
#  [ 6.44185311e-03]
#  [-1.63177636e-03]
#  [ 1.84183610e-03]
#  [-2.92421399e-03]
#  [ 4.69474828e-03]
#  [-3.82281743e-03]
#  [-1.05738092e-02]
#  [-3.40880794e-02]
#  [-3.07479044e-02]
#  [-3.78569732e-03]
#  [-4.51681364e-02]
#  [-8.27246311e-03]
#  [ 4.50108688e-02]
#  [-2.85104849e-02]
#  [ 4.13363494e-02]
#  [-3.45107824e-02]
#  [-1.72009437e-02]
#  [-7.90104129e-02]
#  [ 4.82150524e-02]
#  [-5.01028928e-02]
#  [-9.99448524e-02]
#  [ 8.88084069e-02]
#  [-1.27652197e-01]
#  [ 5.82263126e-02]
#  [-5.32222723e-02]
#  [ 4.69676097e-03]
#  [-4.43276241e-02]
#  [-2.97315010e-02]
#  [ 8.96832325e-02]
#  [ 1.14689904e-02]
#  [ 6.05438311e-02]
#  [-3.42678455e-02]
#  [ 3.29665906e-02]
#  [-1.61423108e-02]
#  [-4.51463627e-02]
#  [ 2.25726571e-02]
#  [-1.52528608e-02]
#  [ 6.79682441e-02]
#  [-1.60433905e-03]
#  [ 3.34893712e-02]
#  [ 1.43834703e-02]
#  [-1.01560594e-02]
#  [ 3.01145596e-02]
#  [-2.22767327e-02]
#  [ 5.79983784e-03]
#  [ 2.64409320e-02]
#  [-1.80428456e-02]
#  [-3.11551152e-02]
#  [ 2.26713006e-02]
#  [-5.39567660e-04]
#  [ 1.38220906e-02]
#  [ 1.46068682e-02]
#  [-5.25617019e-03]
#  [ 2.62367040e-02]
#  [-9.25514332e-03]
#  [-2.84602110e-02]
#  [ 4.24082258e-03]
#  [ 8.99993520e-03]
#  [-7.00388040e-03]
#  [ 1.14389558e-02]
#  [ 1.67307951e-02]
#  [ 1.33069367e-04]
#  [-2.07133658e-02]
#  [-1.76169966e-02]
#  [ 1.14589178e-02]
#  [ 3.91867520e-03]
#  [ 3.10152088e-02]
#  [-1.05397477e-02]
#  [ 1.65139906e-02]
#  [-7.80396831e-03]
#  [ 2.35094569e-03]
#  [ 1.22142850e-02]
#  [ 1.47184475e-02]
#  [-2.11013932e-03]
#  [ 4.80079355e-03]
#  [ 3.74421648e-03]
#  [ 8.17730728e-03]
#  [ 1.35566708e-02]
#  [-3.37438908e-03]
#  [ 2.58740128e-02]
#  [ 1.19696564e-02]
#  [-7.82974342e-03]
#  [-5.32725574e-03]
#  [-6.07526930e-02]
#  [ 1.29762866e-02]
#  [ 8.27786082e-03]
#  [ 1.87848529e-02]
#  [-3.60679623e-03]
#  [ 5.94043404e-04]
#  [-5.66551357e-03]
#  [ 6.47409330e-03]
#  [ 4.29816919e-03]
#  [-2.61952656e-02]
#  [ 1.08998277e-02]
#  [-2.45252043e-02]
#  [ 1.45788881e-02]
#  [ 1.52923494e-02]
#  [ 5.00956398e-03]
#  [ 4.53097048e-03]
#  [ 1.57569308e-02]
#  [-1.08774779e-02]
#  [ 7.79698626e-03]
#  [-5.65959148e-03]
#  [ 1.04118098e-02]
#  [-9.40664522e-03]
#  [ 1.33173006e-02]
#  [ 9.04105694e-03]
#  [-3.41191521e-03]
#  [ 2.84456259e-03]
#  [ 8.37179726e-03]
#  [ 1.67762933e-03]
#  [ 5.73063059e-03]
#  [-1.23963784e-02]
#  [-6.20964002e-03]
#  [ 7.36792882e-03]
#  [-6.49443542e-03]
#  [ 1.23517834e-02]
#  [-3.75730176e-03]
#  [ 7.64123624e-03]
#  [ 7.15536266e-03]
#  [ 3.60542303e-03]
#  [ 6.40916044e-03]
#  [ 6.40712602e-03]
#  [ 6.32829270e-04]
#  [ 2.73846527e-03]
#  [-8.00105540e-03]
#  [ 1.38995023e-02]
#  [-2.04927268e-03]
#  [-1.71897396e-04]
#  [ 2.70617751e-03]
#  [ 2.30074042e-03]
#  [-4.41412335e-03]
#  [ 3.15365477e-03]
#  [ 3.43519998e-03]
#  [ 9.99361536e-03]
#  [ 3.58989975e-03]
#  [ 1.01440013e-02]
#  [ 1.67164603e-03]
#  [ 6.71000285e-03]
#  [-2.19737518e-03]
#  [ 7.49683142e-03]
#  [ 1.52490501e-02]
#  [-3.57575941e-02]
#  [-8.16628075e-03]
#  [-2.81488291e-02]
#  [ 1.99447607e-02]
#  [-1.77412459e-02]
#  [ 5.32930158e-04]
#  [ 1.26613350e-02]
#  [ 5.20578593e-03]
#  [-4.62964689e-03]
#  [-8.44794953e-03]
#  [-1.12455769e-02]
#  [-1.16385640e-02]
#  [ 1.04630164e-02]
#  [-2.40073389e-02]
#  [ 2.98300555e-03]
#  [ 1.58504392e-02]
#  [ 1.59821919e-02]
#  [-4.82428270e-03]
#  [ 8.21984257e-03]
#  [ 5.27894956e-03]
#  [-9.62381287e-03]
#  [ 1.78131090e-02]
#  [-1.40720644e-02]
#  [ 1.72471638e-02]
#  [ 7.97821289e-03]
#  [ 8.75509518e-03]
#  [ 1.62825302e-02]
#  [-6.32689163e-03]
#  [-6.64517208e-03]
#  [-1.52892351e-03]
#  [ 1.34910457e-04]
#  [-1.64646635e-02]
#  [ 4.71619532e-03]
#  [-2.19811401e-03]
#  [ 5.20535400e-03]
#  [ 3.43983832e-03]
#  [-1.87644730e-02]
#  [-3.03020535e-03]
#  [-3.59255421e-02]
#  [ 1.18765249e-02]
#  [-1.22037134e-02]
#  [ 1.22429509e-02]
#  [ 1.76427377e-02]
#  [ 2.18075257e-02]
#  [ 1.92732658e-02]
#  [-2.87756585e-04]
#  [ 1.16319747e-02]
#  [-1.40077522e-03]
#  [ 7.62272836e-03]
#  [-1.00286515e-02]
#  [ 1.35185467e-02]
#  [ 1.15807349e-02]
#  [-4.80344378e-03]
#  [-1.16312106e-02]
#  [ 3.93867569e-03]
#  [-6.81573737e-03]
#  [ 5.62010818e-03]
#  [ 1.60324588e-02]
#  [-1.58567476e-03]
#  [ 2.39411103e-03]
#  [-4.60614064e-03]
#  [ 1.12081407e-02]
#  [ 1.78956453e-03]
#  [-6.24352080e-04]
#  [ 8.79746372e-03]
#  [-1.93751344e-03]
#  [ 2.78327117e-03]
#  [-7.98096495e-03]
#  [-1.28593453e-03]
#  [-1.26579808e-03]
#  [-4.36878825e-03]
#  [ 1.28384820e-02]
#  [ 1.77122562e-03]
#  [ 5.74114281e-03]
#  [-3.51729695e-03]
#  [-3.91392849e-03]
#  [-2.07524469e-03]
#  [ 7.45533272e-04]
#  [ 3.53034998e-03]
#  [ 8.68470754e-03]
#  [-2.22986483e-03]
#  [ 1.34064810e-03]
#  [ 6.41820471e-03]
#  [-1.48647627e-02]
#  [ 7.05763138e-03]
#  [ 5.69360338e-03]
#  [ 1.47382601e-02]
#  [ 5.47683739e-03]
#  [-6.57632762e-03]
#  [ 4.15702031e-04]
#  [ 2.27305639e-03]
#  [-3.76051307e-03]
#  [-7.21600080e-03]
#  [ 8.10345764e-03]
#  [ 1.38394174e-02]
#  [ 3.16673161e-04]
#  [-3.01515266e-03]
#  [ 3.60931751e-03]
#  [-1.48994316e-03]
#  [-2.60133151e-02]
#  [ 9.71329878e-03]
#  [-1.95003777e-02]
#  [ 1.59243002e-02]
#  [ 1.38025288e-02]
#  [ 1.00826062e-03]
#  [ 1.07948476e-02]
#  [ 3.88991961e-03]
#  [ 7.37210748e-03]
#  [-1.11414542e-03]
#  [-3.45244522e-04]
#  [ 1.66107481e-03]
#  [ 4.69997093e-03]
#  [-5.69434515e-04]
#  [-3.20453349e-04]
#  [-4.42561423e-03]
#  [-1.85661910e-03]
#  [-7.76289289e-03]
#  [ 1.25552961e-03]
#  [ 1.12876677e-02]
#  [-2.47833944e-02]
#  [-4.76153229e-03]
#  [ 2.35121732e-02]
#  [-8.11367874e-03]
#  [-1.31523359e-02]
#  [-1.35080381e-02]
#  [ 1.93083563e-02]
#  [-5.37364322e-03]
#  [ 1.40554007e-02]
#  [ 6.01220377e-03]
#  [ 1.03418255e-02]
#  [ 1.01488333e-03]
#  [ 6.47093954e-03]
#  [-1.57091698e-03]
#  [ 2.87524465e-03]
#  [-1.48705601e-02]
#  [-6.02885674e-04]
#  [ 7.00055690e-03]
#  [-7.66011812e-03]
#  [-5.48233660e-03]
#  [ 5.22658343e-03]
#  [ 1.64944187e-02]
#  [-8.68389626e-04]
#  [-3.16282941e-03]
#  [ 3.61595359e-03]
#  [ 1.17558304e-02]
#  [ 1.43349878e-02]
#  [-9.74004941e-04]
#  [ 1.47414570e-03]
#  [ 4.21175094e-03]
#  [ 7.69028814e-03]
#  [-1.96098075e-04]
#  [ 3.28907188e-03]
#  [-4.09610432e-03]
#  [ 1.10331014e-02]
#  [ 3.60232339e-03]
#  [-5.32068989e-03]
#  [-6.82556101e-03]
#  [ 9.26302092e-03]
#  [-9.25333786e-03]
#  [ 1.08694099e-02]
#  [ 1.78068456e-03]
#  [-2.14918981e-04]
#  [-8.45897587e-04]
#  [ 6.74004154e-03]
#  [-7.22071342e-03]
#  [ 2.74432165e-03]
#  [-6.70073749e-03]
#  [ 7.03216447e-04]
#  [ 8.13229950e-03]
#  [ 7.34629142e-03]
#  [-1.04904805e-02]
#  [-8.71175014e-03]
#  [-2.16827824e-02]
#  [ 1.20996446e-02]
#  [ 1.48077786e-02]
#  [-2.53325818e-03]
#  [-8.55377238e-03]
#  [-2.94775181e-03]
#  [ 1.04994293e-02]
#  [-7.84188075e-04]
#  [ 9.86249748e-03]
#  [-2.12754540e-03]
#  [ 1.87505755e-03]
#  [ 1.16463609e-03]
#  [ 7.68586453e-04]
#  [-4.92454759e-04]
#  [ 1.44588904e-03]
#  [-3.63530306e-03]
#  [ 8.79530338e-03]
#  [-7.97056269e-04]
#  [ 1.75009549e-04]
#  [-1.82553259e-03]
#  [ 4.64145478e-03]
#  [ 1.94653893e-03]
#  [ 1.81355639e-03]
#  [-2.01371995e-03]
#  [-5.40470375e-03]
#  [-4.35810544e-04]
#  [-1.32113557e-02]
#  [ 1.39051635e-02]
#  [ 5.11140638e-03]
#  [-1.08387052e-03]
#  [ 5.79442955e-03]
#  [ 3.32506316e-03]
#  [ 2.31228886e-03]
#  [ 2.77297743e-04]
#  [ 1.32727842e-03]
#  [ 5.20804143e-03]
#  [ 7.47209589e-03]
#  [-2.02390277e-03]
#  [ 3.35334655e-03]
#  [-8.59788101e-03]
#  [ 1.12148259e-02]
#  [ 3.44523270e-03]
#  [-3.52301118e-03]
#  [ 1.16425657e-03]
#  [-3.26757356e-03]
#  [-7.56741501e-03]
#  [-1.59967814e-02]
#  [ 1.50488060e-02]
#  [ 8.20804166e-03]
#  [ 2.01463921e-03]
#  [ 1.00943324e-02]
#  [ 2.37936692e-03]
#  [-4.72358338e-03]
#  [-1.86279232e-04]
#  [ 4.19733185e-03]
#  [-5.42071361e-03]
#  [-1.84450567e-03]
#  [ 8.16996134e-03]
#  [-4.64315066e-03]
#  [ 5.98748599e-03]
#  [ 1.67386455e-03]
#  [-9.40350265e-04]
#  [ 9.92186954e-04]
#  [ 1.27493072e-03]
#  [ 4.13780774e-03]
#  [ 1.60601632e-03]
#  [ 2.61742226e-03]
#  [-7.08574351e-03]
#  [-1.08066528e-02]
#  [ 1.25590326e-03]
#  [ 8.10860389e-03]
#  [ 8.48766798e-03]
#  [ 1.49461880e-03]
#  [ 2.21765740e-03]
#  [-5.84194983e-03]
#  [ 8.76907154e-03]
#  [ 4.29732411e-03]
#  [-1.35002692e-03]
#  [ 3.11640061e-04]
#  [ 2.83860575e-03]
#  [-3.35087261e-04]
#  [-3.40135245e-03]
#  [-1.31943681e-03]
#  [-4.61624715e-03]
#  [-7.75255229e-03]
#  [ 2.27390035e-03]
#  [-5.76321397e-03]
#  [ 8.43829422e-03]
#  [-1.55234471e-03]
#  [-9.15263028e-03]
#  [-1.71230777e-02]
#  [-8.12688659e-04]
#  [ 9.47458522e-03]
#  [ 1.20616804e-02]
#  [ 1.45994281e-03]
#  [-2.78024392e-03]
#  [-2.05743177e-02]
#  [ 1.56795434e-03]
#  [-1.19812029e-02]
#  [ 1.14259521e-02]
#  [-1.30709520e-02]
#  [ 1.04695175e-02]
#  [ 4.09439935e-03]
#  [ 8.26403923e-03]
#  [-1.91555660e-03]
#  [-6.88944164e-03]
#  [-2.41970569e-03]
#  [ 3.01795587e-03]
#  [ 1.69191623e-02]
#  [ 7.43252064e-03]
#  [ 3.36908780e-03]
#  [ 7.36614278e-03]
#  [ 3.65733360e-03]
#  [ 2.99139317e-03]
#  [-1.07312922e-03]
#  [ 4.73695944e-03]
#  [ 1.81814143e-03]
#  [-5.06437037e-03]
#  [ 9.78128842e-03]
#  [ 1.94743723e-03]
#  [ 1.79845895e-03]
#  [ 3.67360712e-03]
#  [ 6.44049461e-03]
#  [ 4.17322234e-03]
#  [ 3.72585005e-03]
#  [ 8.87394061e-04]
#  [-3.50491093e-03]
#  [-8.25984216e-03]
#  [ 5.50788333e-04]
#  [ 7.19669756e-03]
#  [-1.07398780e-05]
#  [ 3.85777906e-03]
#  [-2.60501548e-03]
#  [ 3.37906474e-03]
#  [-1.39964460e-03]
#  [-3.20225832e-03]
#  [ 1.65576138e-03]
#  [ 2.29122378e-03]
#  [-2.29870112e-02]
#  [ 1.31138361e-02]
#  [-1.91433812e-02]
#  [-1.18855415e-02]
#  [ 1.40946384e-02]
#  [-8.48445514e-03]
#  [ 1.16625993e-02]
#  [ 2.04956032e-02]
#  [ 3.08053559e-03]
#  [-7.20698823e-03]
#  [ 9.50376912e-03]
#  [-9.17815834e-03]
#  [-7.49872285e-03]
#  [ 1.62162674e-02]
#  [-8.78186331e-03]
#  [-1.03409646e-02]
#  [-1.14533983e-02]
#  [ 1.76217554e-02]
#  [ 1.01287280e-02]
#  [ 6.20441269e-03]
#  [ 1.37440516e-02]
#  [-1.01066540e-03]
#  [ 1.40091340e-03]
#  [-2.99423384e-03]
#  [-2.62963437e-03]
#  [ 6.35382417e-03]
#  [-6.29820252e-04]
#  [-1.95832643e-02]
#  [-9.64233740e-04]
#  [-4.05844108e-03]
#  [-1.44207054e-03]
#  [ 9.11828645e-03]
#  [ 2.81379201e-03]
#  [-1.43460292e-02]
#  [ 8.19644270e-04]
#  [-1.85591054e-02]
#  [-9.73679094e-03]
#  [-1.10987423e-02]
#  [-1.90959953e-02]
#  [ 2.76790476e-03]
#  [-1.22465906e-02]
#  [-1.49775693e-03]
#  [-5.39863520e-03]
#  [ 2.40559679e-02]
#  [ 1.87098262e-02]
#  [ 6.83956035e-03]
#  [ 9.37840045e-03]
#  [-2.46934717e-02]
#  [ 5.14367844e-03]
#  [-3.70858093e-03]
#  [ 8.36611347e-03]
#  [ 1.44128421e-02]
#  [-1.82818245e-02]
#  [-1.91516826e-02]
#  [-3.84799076e-03]
#  [ 1.56437176e-02]
#  [ 8.80819720e-04]
#  [-2.14005041e-02]
#  [-7.19196166e-03]
#  [-1.01947354e-02]
#  [-1.85837357e-02]
#  [ 1.48461053e-02]
#  [ 2.21260806e-02]
#  [-2.44559146e-03]
#  [-1.55944678e-02]
#  [ 1.84710468e-02]
#  [-5.26852074e-03]
#  [-7.96568454e-03]
#  [-2.99625868e-02]
#  [-7.26004398e-03]
#  [ 2.53735981e-02]
#  [-4.30104992e-03]
#  [-1.30462789e-02]
#  [-7.44867510e-03]
#  [ 2.11826297e-02]
#  [ 2.21369216e-02]
#  [ 1.22722051e-02]
#  [ 1.15948144e-02]
#  [-4.34754854e-04]
#  [ 1.12406996e-02]
#  [-1.23486303e-02]
#  [ 1.42420123e-02]
#  [ 5.05338070e-03]
#  [ 7.11955102e-03]
#  [ 1.21820441e-02]
#  [-6.31358900e-03]
#  [-1.57763352e-02]
#  [ 3.40442096e-03]
#  [ 8.05838253e-03]
#  [-1.26311591e-02]
#  [-9.76443391e-03]
#  [ 4.24436555e-03]
#  [-2.65454668e-03]
#  [-1.70213346e-02]
#  [-3.42330053e-03]
#  [ 1.11126033e-02]
#  [-1.22184804e-02]
#  [-2.04889272e-04]
#  [ 1.59300447e-02]
#  [-6.18666406e-04]
#  [-1.48628556e-02]
#  [-2.81320764e-02]
#  [ 5.68176514e-03]
#  [-2.85500089e-02]
#  [ 2.09584902e-03]
#  [ 2.44456553e-02]
#  [-3.69591598e-02]
#  [ 5.65919929e-03]
#  [ 4.82546508e-03]
#  [ 2.94252216e-02]
#  [-3.63006776e-02]
#  [-5.69038441e-03]
#  [-3.25615195e-02]
#  [ 2.45488176e-03]
#  [-1.66002321e-02]
#  [-1.29680499e-03]
#  [ 2.35892680e-02]
#  [-3.95420852e-03]
#  [ 1.99689196e-02]
#  [-4.12338093e-02]
#  [-5.85086478e-03]
#  [ 1.46131092e-04]
#  [ 1.83849954e-02]
#  [-8.15395090e-03]
#  [ 9.40638565e-03]
#  [ 1.96881660e-02]
#  [ 2.44411302e-02]
#  [-6.29413519e-03]
#  [-7.51090504e-03]
#  [ 1.82632254e-02]
#  [-1.64824056e-02]
#  [ 3.13248941e-03]
#  [ 9.47833153e-03]
#  [-1.08526230e-02]
#  [-2.40864577e-02]
#  [-2.95424148e-02]
#  [-3.95399320e-02]
#  [-3.78081804e-03]
#  [ 1.44870588e-02]
#  [-3.30522071e-02]
#  [ 2.19844734e-03]
#  [ 2.41824750e-02]
#  [-1.30242010e-03]
#  [ 9.48707249e-03]
#  [ 3.01055397e-02]
#  [-2.97749989e-03]
#  [-2.03486731e-02]
#  [-7.11998820e-04]
#  [-8.79786625e-03]
#  [ 1.04985113e-02]
#  [ 1.58287511e-03]
#  [ 3.56679571e-03]
#  [ 1.48537232e-02]
#  [-8.30616396e-04]
#  [-1.15944177e-02]
#  [-9.28686850e-03]
#  [-4.46686411e-03]
#  [-3.00313881e-03]
#  [ 1.90192317e-02]
#  [-8.39874249e-03]
#  [ 2.72535176e-02]
#  [ 5.87849394e-03]
#  [ 9.81306669e-03]
#  [-9.37628729e-03]
#  [ 1.31430297e-03]
#  [-1.16103426e-02]
#  [ 2.58200488e-02]
#  [ 1.20603198e-02]
#  [ 1.41077758e-02]
#  [-2.82707654e-03]
#  [-6.68468838e-03]
#  [ 1.55174563e-02]
#  [-7.77642450e-04]
#  [-1.62706902e-03]
#  [-1.23831712e-03]
#  [-4.25774424e-03]
#  [ 2.10671585e-02]
#  [-7.05722922e-04]
#  [ 1.71740470e-02]
#  [ 3.96168406e-03]
#  [ 1.87392283e-03]
#  [-7.26411487e-03]
#  [ 2.26698961e-03]
#  [-1.29839287e-02]
#  [-2.16323665e-02]
#  [-2.24037043e-03]
#  [ 2.91191670e-03]
#  [ 1.39932418e-02]
#  [-3.42685763e-02]
#  [-6.68867520e-03]
#  [-1.10894165e-02]
#  [-7.84773821e-03]
#  [ 2.99175227e-03]
#  [-1.07945526e-02]
#  [-4.10346469e-03]
#  [ 1.81748487e-02]
#  [ 6.58896688e-03]
#  [ 1.51560150e-02]
#  [ 1.05286515e-02]
#  [-4.41991630e-02]
#  [ 3.38128908e-03]
#  [-1.13822722e-02]
#  [-7.20804978e-03]
#  [ 6.83369772e-03]
#  [-1.13361147e-02]
#  [-1.72646741e-02]
#  [-8.46329383e-03]
#  [-1.73828288e-02]
#  [-1.03943609e-02]
#  [-2.12261095e-03]
#  [ 1.94811442e-02]
#  [-2.13527948e-02]
#  [-1.51813515e-02]
#  [ 2.55545775e-02]
#  [ 3.01253414e-02]
#  [-2.01998756e-03]
#  [-1.02979229e-02]
#  [-2.84031965e-02]
#  [-7.52067313e-03]
#  [-6.54051841e-03]
#  [-3.29619965e-03]
#  [ 2.56342593e-02]
#  [-2.39471207e-02]
#  [ 2.61355246e-02]
#  [ 1.13627682e-02]
#  [-6.69445524e-03]
#  [-7.98268674e-03]
#  [ 2.34477599e-02]
#  [ 1.18119402e-02]
#  [ 1.61357700e-02]
#  [-7.41514040e-03]
#  [-6.10118505e-03]
#  [ 2.43280368e-02]
#  [-7.48232703e-03]
#  [-4.10966372e-03]
#  [-2.53198437e-02]
#  [-1.06424225e-02]
#  [ 1.35268233e-02]
#  [ 9.56806168e-03]
#  [ 5.58228283e-03]
#  [-2.09967847e-02]
#  [ 5.39525157e-02]
#  [ 9.19831230e-03]
#  [-8.97594054e-03]
#  [ 8.67537641e-03]
#  [-8.28628311e-03]
#  [-3.09410464e-03]
#  [ 4.74729565e-03]
#  [-3.89124980e-03]
#  [ 1.34886063e-02]
#  [ 5.89726604e-03]
#  [-2.83084262e-04]
#  [-1.55646968e-02]
#  [-1.59313370e-03]
#  [ 3.04786435e-02]
#  [-8.68009830e-04]
#  [-1.19537466e-03]
#  [-1.80562496e-02]
#  [-1.45038694e-02]
#  [-1.86410725e-03]
#  [ 7.49363441e-03]
#  [-7.37671946e-03]
#  [ 1.41783073e-02]
#  [ 7.26322326e-03]
#  [-6.07111662e-03]
#  [-2.52374779e-02]
#  [-1.12002399e-02]
#  [-9.04832894e-03]
#  [ 1.03680070e-03]
#  [ 1.47585487e-02]
#  [-1.45571425e-02]
#  [ 5.85095227e-03]
#  [-4.05784403e-03]
#  [-1.20934704e-02]
#  [ 1.73106343e-02]]

# %%
fig, axes = plt.subplots(1, 2, sharex = True)
axes[0].plot(ndarray); axes[0].set_title('Order of Differencing: First')  
axes[1].set(ylim = (0,5))  
plot_pacf(ndarray, ax = axes[1])
# Out:
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# Look a the blue region to determine if it is useful or not
# In the PAC graph, there should be a light blue box showing the significance-- need to fix this 
# Otherwise, for PAC I would say there is an order of 1 or 2 at the moment

# %%
#Next, finding the 'q' - Moving Averages
import numpy as np, pandas as pd  
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf  
import matplotlib.pyplot as plt  
  
plt.rcParams.update({'figure.figsize' : (9,3), 'figure.dpi' : 120})

# %%
# Importing data  
mydata = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)

# %%
 plt.plot(df.to_numpy(), label='Close')

# %%
mydata = np.asarray(df)
print(mydata)
# Out:
# [[-7.08490936e-03]
#  [ 3.52714519e-03]
#  [-2.80717508e-03]
#  [ 4.89047349e-03]
#  [ 6.63321412e-03]
#  [-2.85926249e-03]
#  [ 6.95199405e-03]
#  [-1.51568084e-03]
#  [ 1.86845024e-03]
#  [ 8.33174742e-03]
#  [ 3.85472325e-03]
#  [-2.65550037e-03]
#  [ 2.89034297e-04]
#  [ 1.14032619e-03]
#  [-9.08328943e-03]
#  [-1.58557524e-02]
#  [ 1.00033835e-02]
#  [-8.67250144e-04]
#  [ 3.12945693e-03]
#  [-1.78644436e-02]
#  [ 7.22842576e-03]
#  [ 1.48693159e-02]
#  [ 1.11877787e-02]
#  [ 3.32015506e-03]
#  [-5.41549101e-03]
#  [ 7.29969012e-03]
#  [ 1.68704869e-03]
#  [ 6.44185311e-03]
#  [-1.63177636e-03]
#  [ 1.84183610e-03]
#  [-2.92421399e-03]
#  [ 4.69474828e-03]
#  [-3.82281743e-03]
#  [-1.05738092e-02]
#  [-3.40880794e-02]
#  [-3.07479044e-02]
#  [-3.78569732e-03]
#  [-4.51681364e-02]
#  [-8.27246311e-03]
#  [ 4.50108688e-02]
#  [-2.85104849e-02]
#  [ 4.13363494e-02]
#  [-3.45107824e-02]
#  [-1.72009437e-02]
#  [-7.90104129e-02]
#  [ 4.82150524e-02]
#  [-5.01028928e-02]
#  [-9.99448524e-02]
#  [ 8.88084069e-02]
#  [-1.27652197e-01]
#  [ 5.82263126e-02]
#  [-5.32222723e-02]
#  [ 4.69676097e-03]
#  [-4.43276241e-02]
#  [-2.97315010e-02]
#  [ 8.96832325e-02]
#  [ 1.14689904e-02]
#  [ 6.05438311e-02]
#  [-3.42678455e-02]
#  [ 3.29665906e-02]
#  [-1.61423108e-02]
#  [-4.51463627e-02]
#  [ 2.25726571e-02]
#  [-1.52528608e-02]
#  [ 6.79682441e-02]
#  [-1.60433905e-03]
#  [ 3.34893712e-02]
#  [ 1.43834703e-02]
#  [-1.01560594e-02]
#  [ 3.01145596e-02]
#  [-2.22767327e-02]
#  [ 5.79983784e-03]
#  [ 2.64409320e-02]
#  [-1.80428456e-02]
#  [-3.11551152e-02]
#  [ 2.26713006e-02]
#  [-5.39567660e-04]
#  [ 1.38220906e-02]
#  [ 1.46068682e-02]
#  [-5.25617019e-03]
#  [ 2.62367040e-02]
#  [-9.25514332e-03]
#  [-2.84602110e-02]
#  [ 4.24082258e-03]
#  [ 8.99993520e-03]
#  [-7.00388040e-03]
#  [ 1.14389558e-02]
#  [ 1.67307951e-02]
#  [ 1.33069367e-04]
#  [-2.07133658e-02]
#  [-1.76169966e-02]
#  [ 1.14589178e-02]
#  [ 3.91867520e-03]
#  [ 3.10152088e-02]
#  [-1.05397477e-02]
#  [ 1.65139906e-02]
#  [-7.80396831e-03]
#  [ 2.35094569e-03]
#  [ 1.22142850e-02]
#  [ 1.47184475e-02]
#  [-2.11013932e-03]
#  [ 4.80079355e-03]
#  [ 3.74421648e-03]
#  [ 8.17730728e-03]
#  [ 1.35566708e-02]
#  [-3.37438908e-03]
#  [ 2.58740128e-02]
#  [ 1.19696564e-02]
#  [-7.82974342e-03]
#  [-5.32725574e-03]
#  [-6.07526930e-02]
#  [ 1.29762866e-02]
#  [ 8.27786082e-03]
#  [ 1.87848529e-02]
#  [-3.60679623e-03]
#  [ 5.94043404e-04]
#  [-5.66551357e-03]
#  [ 6.47409330e-03]
#  [ 4.29816919e-03]
#  [-2.61952656e-02]
#  [ 1.08998277e-02]
#  [-2.45252043e-02]
#  [ 1.45788881e-02]
#  [ 1.52923494e-02]
#  [ 5.00956398e-03]
#  [ 4.53097048e-03]
#  [ 1.57569308e-02]
#  [-1.08774779e-02]
#  [ 7.79698626e-03]
#  [-5.65959148e-03]
#  [ 1.04118098e-02]
#  [-9.40664522e-03]
#  [ 1.33173006e-02]
#  [ 9.04105694e-03]
#  [-3.41191521e-03]
#  [ 2.84456259e-03]
#  [ 8.37179726e-03]
#  [ 1.67762933e-03]
#  [ 5.73063059e-03]
#  [-1.23963784e-02]
#  [-6.20964002e-03]
#  [ 7.36792882e-03]
#  [-6.49443542e-03]
#  [ 1.23517834e-02]
#  [-3.75730176e-03]
#  [ 7.64123624e-03]
#  [ 7.15536266e-03]
#  [ 3.60542303e-03]
#  [ 6.40916044e-03]
#  [ 6.40712602e-03]
#  [ 6.32829270e-04]
#  [ 2.73846527e-03]
#  [-8.00105540e-03]
#  [ 1.38995023e-02]
#  [-2.04927268e-03]
#  [-1.71897396e-04]
#  [ 2.70617751e-03]
#  [ 2.30074042e-03]
#  [-4.41412335e-03]
#  [ 3.15365477e-03]
#  [ 3.43519998e-03]
#  [ 9.99361536e-03]
#  [ 3.58989975e-03]
#  [ 1.01440013e-02]
#  [ 1.67164603e-03]
#  [ 6.71000285e-03]
#  [-2.19737518e-03]
#  [ 7.49683142e-03]
#  [ 1.52490501e-02]
#  [-3.57575941e-02]
#  [-8.16628075e-03]
#  [-2.81488291e-02]
#  [ 1.99447607e-02]
#  [-1.77412459e-02]
#  [ 5.32930158e-04]
#  [ 1.26613350e-02]
#  [ 5.20578593e-03]
#  [-4.62964689e-03]
#  [-8.44794953e-03]
#  [-1.12455769e-02]
#  [-1.16385640e-02]
#  [ 1.04630164e-02]
#  [-2.40073389e-02]
#  [ 2.98300555e-03]
#  [ 1.58504392e-02]
#  [ 1.59821919e-02]
#  [-4.82428270e-03]
#  [ 8.21984257e-03]
#  [ 5.27894956e-03]
#  [-9.62381287e-03]
#  [ 1.78131090e-02]
#  [-1.40720644e-02]
#  [ 1.72471638e-02]
#  [ 7.97821289e-03]
#  [ 8.75509518e-03]
#  [ 1.62825302e-02]
#  [-6.32689163e-03]
#  [-6.64517208e-03]
#  [-1.52892351e-03]
#  [ 1.34910457e-04]
#  [-1.64646635e-02]
#  [ 4.71619532e-03]
#  [-2.19811401e-03]
#  [ 5.20535400e-03]
#  [ 3.43983832e-03]
#  [-1.87644730e-02]
#  [-3.03020535e-03]
#  [-3.59255421e-02]
#  [ 1.18765249e-02]
#  [-1.22037134e-02]
#  [ 1.22429509e-02]
#  [ 1.76427377e-02]
#  [ 2.18075257e-02]
#  [ 1.92732658e-02]
#  [-2.87756585e-04]
#  [ 1.16319747e-02]
#  [-1.40077522e-03]
#  [ 7.62272836e-03]
#  [-1.00286515e-02]
#  [ 1.35185467e-02]
#  [ 1.15807349e-02]
#  [-4.80344378e-03]
#  [-1.16312106e-02]
#  [ 3.93867569e-03]
#  [-6.81573737e-03]
#  [ 5.62010818e-03]
#  [ 1.60324588e-02]
#  [-1.58567476e-03]
#  [ 2.39411103e-03]
#  [-4.60614064e-03]
#  [ 1.12081407e-02]
#  [ 1.78956453e-03]
#  [-6.24352080e-04]
#  [ 8.79746372e-03]
#  [-1.93751344e-03]
#  [ 2.78327117e-03]
#  [-7.98096495e-03]
#  [-1.28593453e-03]
#  [-1.26579808e-03]
#  [-4.36878825e-03]
#  [ 1.28384820e-02]
#  [ 1.77122562e-03]
#  [ 5.74114281e-03]
#  [-3.51729695e-03]
#  [-3.91392849e-03]
#  [-2.07524469e-03]
#  [ 7.45533272e-04]
#  [ 3.53034998e-03]
#  [ 8.68470754e-03]
#  [-2.22986483e-03]
#  [ 1.34064810e-03]
#  [ 6.41820471e-03]
#  [-1.48647627e-02]
#  [ 7.05763138e-03]
#  [ 5.69360338e-03]
#  [ 1.47382601e-02]
#  [ 5.47683739e-03]
#  [-6.57632762e-03]
#  [ 4.15702031e-04]
#  [ 2.27305639e-03]
#  [-3.76051307e-03]
#  [-7.21600080e-03]
#  [ 8.10345764e-03]
#  [ 1.38394174e-02]
#  [ 3.16673161e-04]
#  [-3.01515266e-03]
#  [ 3.60931751e-03]
#  [-1.48994316e-03]
#  [-2.60133151e-02]
#  [ 9.71329878e-03]
#  [-1.95003777e-02]
#  [ 1.59243002e-02]
#  [ 1.38025288e-02]
#  [ 1.00826062e-03]
#  [ 1.07948476e-02]
#  [ 3.88991961e-03]
#  [ 7.37210748e-03]
#  [-1.11414542e-03]
#  [-3.45244522e-04]
#  [ 1.66107481e-03]
#  [ 4.69997093e-03]
#  [-5.69434515e-04]
#  [-3.20453349e-04]
#  [-4.42561423e-03]
#  [-1.85661910e-03]
#  [-7.76289289e-03]
#  [ 1.25552961e-03]
#  [ 1.12876677e-02]
#  [-2.47833944e-02]
#  [-4.76153229e-03]
#  [ 2.35121732e-02]
#  [-8.11367874e-03]
#  [-1.31523359e-02]
#  [-1.35080381e-02]
#  [ 1.93083563e-02]
#  [-5.37364322e-03]
#  [ 1.40554007e-02]
#  [ 6.01220377e-03]
#  [ 1.03418255e-02]
#  [ 1.01488333e-03]
#  [ 6.47093954e-03]
#  [-1.57091698e-03]
#  [ 2.87524465e-03]
#  [-1.48705601e-02]
#  [-6.02885674e-04]
#  [ 7.00055690e-03]
#  [-7.66011812e-03]
#  [-5.48233660e-03]
#  [ 5.22658343e-03]
#  [ 1.64944187e-02]
#  [-8.68389626e-04]
#  [-3.16282941e-03]
#  [ 3.61595359e-03]
#  [ 1.17558304e-02]
#  [ 1.43349878e-02]
#  [-9.74004941e-04]
#  [ 1.47414570e-03]
#  [ 4.21175094e-03]
#  [ 7.69028814e-03]
#  [-1.96098075e-04]
#  [ 3.28907188e-03]
#  [-4.09610432e-03]
#  [ 1.10331014e-02]
#  [ 3.60232339e-03]
#  [-5.32068989e-03]
#  [-6.82556101e-03]
#  [ 9.26302092e-03]
#  [-9.25333786e-03]
#  [ 1.08694099e-02]
#  [ 1.78068456e-03]
#  [-2.14918981e-04]
#  [-8.45897587e-04]
#  [ 6.74004154e-03]
#  [-7.22071342e-03]
#  [ 2.74432165e-03]
#  [-6.70073749e-03]
#  [ 7.03216447e-04]
#  [ 8.13229950e-03]
#  [ 7.34629142e-03]
#  [-1.04904805e-02]
#  [-8.71175014e-03]
#  [-2.16827824e-02]
#  [ 1.20996446e-02]
#  [ 1.48077786e-02]
#  [-2.53325818e-03]
#  [-8.55377238e-03]
#  [-2.94775181e-03]
#  [ 1.04994293e-02]
#  [-7.84188075e-04]
#  [ 9.86249748e-03]
#  [-2.12754540e-03]
#  [ 1.87505755e-03]
#  [ 1.16463609e-03]
#  [ 7.68586453e-04]
#  [-4.92454759e-04]
#  [ 1.44588904e-03]
#  [-3.63530306e-03]
#  [ 8.79530338e-03]
#  [-7.97056269e-04]
#  [ 1.75009549e-04]
#  [-1.82553259e-03]
#  [ 4.64145478e-03]
#  [ 1.94653893e-03]
#  [ 1.81355639e-03]
#  [-2.01371995e-03]
#  [-5.40470375e-03]
#  [-4.35810544e-04]
#  [-1.32113557e-02]
#  [ 1.39051635e-02]
#  [ 5.11140638e-03]
#  [-1.08387052e-03]
#  [ 5.79442955e-03]
#  [ 3.32506316e-03]
#  [ 2.31228886e-03]
#  [ 2.77297743e-04]
#  [ 1.32727842e-03]
#  [ 5.20804143e-03]
#  [ 7.47209589e-03]
#  [-2.02390277e-03]
#  [ 3.35334655e-03]
#  [-8.59788101e-03]
#  [ 1.12148259e-02]
#  [ 3.44523270e-03]
#  [-3.52301118e-03]
#  [ 1.16425657e-03]
#  [-3.26757356e-03]
#  [-7.56741501e-03]
#  [-1.59967814e-02]
#  [ 1.50488060e-02]
#  [ 8.20804166e-03]
#  [ 2.01463921e-03]
#  [ 1.00943324e-02]
#  [ 2.37936692e-03]
#  [-4.72358338e-03]
#  [-1.86279232e-04]
#  [ 4.19733185e-03]
#  [-5.42071361e-03]
#  [-1.84450567e-03]
#  [ 8.16996134e-03]
#  [-4.64315066e-03]
#  [ 5.98748599e-03]
#  [ 1.67386455e-03]
#  [-9.40350265e-04]
#  [ 9.92186954e-04]
#  [ 1.27493072e-03]
#  [ 4.13780774e-03]
#  [ 1.60601632e-03]
#  [ 2.61742226e-03]
#  [-7.08574351e-03]
#  [-1.08066528e-02]
#  [ 1.25590326e-03]
#  [ 8.10860389e-03]
#  [ 8.48766798e-03]
#  [ 1.49461880e-03]
#  [ 2.21765740e-03]
#  [-5.84194983e-03]
#  [ 8.76907154e-03]
#  [ 4.29732411e-03]
#  [-1.35002692e-03]
#  [ 3.11640061e-04]
#  [ 2.83860575e-03]
#  [-3.35087261e-04]
#  [-3.40135245e-03]
#  [-1.31943681e-03]
#  [-4.61624715e-03]
#  [-7.75255229e-03]
#  [ 2.27390035e-03]
#  [-5.76321397e-03]
#  [ 8.43829422e-03]
#  [-1.55234471e-03]
#  [-9.15263028e-03]
#  [-1.71230777e-02]
#  [-8.12688659e-04]
#  [ 9.47458522e-03]
#  [ 1.20616804e-02]
#  [ 1.45994281e-03]
#  [-2.78024392e-03]
#  [-2.05743177e-02]
#  [ 1.56795434e-03]
#  [-1.19812029e-02]
#  [ 1.14259521e-02]
#  [-1.30709520e-02]
#  [ 1.04695175e-02]
#  [ 4.09439935e-03]
#  [ 8.26403923e-03]
#  [-1.91555660e-03]
#  [-6.88944164e-03]
#  [-2.41970569e-03]
#  [ 3.01795587e-03]
#  [ 1.69191623e-02]
#  [ 7.43252064e-03]
#  [ 3.36908780e-03]
#  [ 7.36614278e-03]
#  [ 3.65733360e-03]
#  [ 2.99139317e-03]
#  [-1.07312922e-03]
#  [ 4.73695944e-03]
#  [ 1.81814143e-03]
#  [-5.06437037e-03]
#  [ 9.78128842e-03]
#  [ 1.94743723e-03]
#  [ 1.79845895e-03]
#  [ 3.67360712e-03]
#  [ 6.44049461e-03]
#  [ 4.17322234e-03]
#  [ 3.72585005e-03]
#  [ 8.87394061e-04]
#  [-3.50491093e-03]
#  [-8.25984216e-03]
#  [ 5.50788333e-04]
#  [ 7.19669756e-03]
#  [-1.07398780e-05]
#  [ 3.85777906e-03]
#  [-2.60501548e-03]
#  [ 3.37906474e-03]
#  [-1.39964460e-03]
#  [-3.20225832e-03]
#  [ 1.65576138e-03]
#  [ 2.29122378e-03]
#  [-2.29870112e-02]
#  [ 1.31138361e-02]
#  [-1.91433812e-02]
#  [-1.18855415e-02]
#  [ 1.40946384e-02]
#  [-8.48445514e-03]
#  [ 1.16625993e-02]
#  [ 2.04956032e-02]
#  [ 3.08053559e-03]
#  [-7.20698823e-03]
#  [ 9.50376912e-03]
#  [-9.17815834e-03]
#  [-7.49872285e-03]
#  [ 1.62162674e-02]
#  [-8.78186331e-03]
#  [-1.03409646e-02]
#  [-1.14533983e-02]
#  [ 1.76217554e-02]
#  [ 1.01287280e-02]
#  [ 6.20441269e-03]
#  [ 1.37440516e-02]
#  [-1.01066540e-03]
#  [ 1.40091340e-03]
#  [-2.99423384e-03]
#  [-2.62963437e-03]
#  [ 6.35382417e-03]
#  [-6.29820252e-04]
#  [-1.95832643e-02]
#  [-9.64233740e-04]
#  [-4.05844108e-03]
#  [-1.44207054e-03]
#  [ 9.11828645e-03]
#  [ 2.81379201e-03]
#  [-1.43460292e-02]
#  [ 8.19644270e-04]
#  [-1.85591054e-02]
#  [-9.73679094e-03]
#  [-1.10987423e-02]
#  [-1.90959953e-02]
#  [ 2.76790476e-03]
#  [-1.22465906e-02]
#  [-1.49775693e-03]
#  [-5.39863520e-03]
#  [ 2.40559679e-02]
#  [ 1.87098262e-02]
#  [ 6.83956035e-03]
#  [ 9.37840045e-03]
#  [-2.46934717e-02]
#  [ 5.14367844e-03]
#  [-3.70858093e-03]
#  [ 8.36611347e-03]
#  [ 1.44128421e-02]
#  [-1.82818245e-02]
#  [-1.91516826e-02]
#  [-3.84799076e-03]
#  [ 1.56437176e-02]
#  [ 8.80819720e-04]
#  [-2.14005041e-02]
#  [-7.19196166e-03]
#  [-1.01947354e-02]
#  [-1.85837357e-02]
#  [ 1.48461053e-02]
#  [ 2.21260806e-02]
#  [-2.44559146e-03]
#  [-1.55944678e-02]
#  [ 1.84710468e-02]
#  [-5.26852074e-03]
#  [-7.96568454e-03]
#  [-2.99625868e-02]
#  [-7.26004398e-03]
#  [ 2.53735981e-02]
#  [-4.30104992e-03]
#  [-1.30462789e-02]
#  [-7.44867510e-03]
#  [ 2.11826297e-02]
#  [ 2.21369216e-02]
#  [ 1.22722051e-02]
#  [ 1.15948144e-02]
#  [-4.34754854e-04]
#  [ 1.12406996e-02]
#  [-1.23486303e-02]
#  [ 1.42420123e-02]
#  [ 5.05338070e-03]
#  [ 7.11955102e-03]
#  [ 1.21820441e-02]
#  [-6.31358900e-03]
#  [-1.57763352e-02]
#  [ 3.40442096e-03]
#  [ 8.05838253e-03]
#  [-1.26311591e-02]
#  [-9.76443391e-03]
#  [ 4.24436555e-03]
#  [-2.65454668e-03]
#  [-1.70213346e-02]
#  [-3.42330053e-03]
#  [ 1.11126033e-02]
#  [-1.22184804e-02]
#  [-2.04889272e-04]
#  [ 1.59300447e-02]
#  [-6.18666406e-04]
#  [-1.48628556e-02]
#  [-2.81320764e-02]
#  [ 5.68176514e-03]
#  [-2.85500089e-02]
#  [ 2.09584902e-03]
#  [ 2.44456553e-02]
#  [-3.69591598e-02]
#  [ 5.65919929e-03]
#  [ 4.82546508e-03]
#  [ 2.94252216e-02]
#  [-3.63006776e-02]
#  [-5.69038441e-03]
#  [-3.25615195e-02]
#  [ 2.45488176e-03]
#  [-1.66002321e-02]
#  [-1.29680499e-03]
#  [ 2.35892680e-02]
#  [-3.95420852e-03]
#  [ 1.99689196e-02]
#  [-4.12338093e-02]
#  [-5.85086478e-03]
#  [ 1.46131092e-04]
#  [ 1.83849954e-02]
#  [-8.15395090e-03]
#  [ 9.40638565e-03]
#  [ 1.96881660e-02]
#  [ 2.44411302e-02]
#  [-6.29413519e-03]
#  [-7.51090504e-03]
#  [ 1.82632254e-02]
#  [-1.64824056e-02]
#  [ 3.13248941e-03]
#  [ 9.47833153e-03]
#  [-1.08526230e-02]
#  [-2.40864577e-02]
#  [-2.95424148e-02]
#  [-3.95399320e-02]
#  [-3.78081804e-03]
#  [ 1.44870588e-02]
#  [-3.30522071e-02]
#  [ 2.19844734e-03]
#  [ 2.41824750e-02]
#  [-1.30242010e-03]
#  [ 9.48707249e-03]
#  [ 3.01055397e-02]
#  [-2.97749989e-03]
#  [-2.03486731e-02]
#  [-7.11998820e-04]
#  [-8.79786625e-03]
#  [ 1.04985113e-02]
#  [ 1.58287511e-03]
#  [ 3.56679571e-03]
#  [ 1.48537232e-02]
#  [-8.30616396e-04]
#  [-1.15944177e-02]
#  [-9.28686850e-03]
#  [-4.46686411e-03]
#  [-3.00313881e-03]
#  [ 1.90192317e-02]
#  [-8.39874249e-03]
#  [ 2.72535176e-02]
#  [ 5.87849394e-03]
#  [ 9.81306669e-03]
#  [-9.37628729e-03]
#  [ 1.31430297e-03]
#  [-1.16103426e-02]
#  [ 2.58200488e-02]
#  [ 1.20603198e-02]
#  [ 1.41077758e-02]
#  [-2.82707654e-03]
#  [-6.68468838e-03]
#  [ 1.55174563e-02]
#  [-7.77642450e-04]
#  [-1.62706902e-03]
#  [-1.23831712e-03]
#  [-4.25774424e-03]
#  [ 2.10671585e-02]
#  [-7.05722922e-04]
#  [ 1.71740470e-02]
#  [ 3.96168406e-03]
#  [ 1.87392283e-03]
#  [-7.26411487e-03]
#  [ 2.26698961e-03]
#  [-1.29839287e-02]
#  [-2.16323665e-02]
#  [-2.24037043e-03]
#  [ 2.91191670e-03]
#  [ 1.39932418e-02]
#  [-3.42685763e-02]
#  [-6.68867520e-03]
#  [-1.10894165e-02]
#  [-7.84773821e-03]
#  [ 2.99175227e-03]
#  [-1.07945526e-02]
#  [-4.10346469e-03]
#  [ 1.81748487e-02]
#  [ 6.58896688e-03]
#  [ 1.51560150e-02]
#  [ 1.05286515e-02]
#  [-4.41991630e-02]
#  [ 3.38128908e-03]
#  [-1.13822722e-02]
#  [-7.20804978e-03]
#  [ 6.83369772e-03]
#  [-1.13361147e-02]
#  [-1.72646741e-02]
#  [-8.46329383e-03]
#  [-1.73828288e-02]
#  [-1.03943609e-02]
#  [-2.12261095e-03]
#  [ 1.94811442e-02]
#  [-2.13527948e-02]
#  [-1.51813515e-02]
#  [ 2.55545775e-02]
#  [ 3.01253414e-02]
#  [-2.01998756e-03]
#  [-1.02979229e-02]
#  [-2.84031965e-02]
#  [-7.52067313e-03]
#  [-6.54051841e-03]
#  [-3.29619965e-03]
#  [ 2.56342593e-02]
#  [-2.39471207e-02]
#  [ 2.61355246e-02]
#  [ 1.13627682e-02]
#  [-6.69445524e-03]
#  [-7.98268674e-03]
#  [ 2.34477599e-02]
#  [ 1.18119402e-02]
#  [ 1.61357700e-02]
#  [-7.41514040e-03]
#  [-6.10118505e-03]
#  [ 2.43280368e-02]
#  [-7.48232703e-03]
#  [-4.10966372e-03]
#  [-2.53198437e-02]
#  [-1.06424225e-02]
#  [ 1.35268233e-02]
#  [ 9.56806168e-03]
#  [ 5.58228283e-03]
#  [-2.09967847e-02]
#  [ 5.39525157e-02]
#  [ 9.19831230e-03]
#  [-8.97594054e-03]
#  [ 8.67537641e-03]
#  [-8.28628311e-03]
#  [-3.09410464e-03]
#  [ 4.74729565e-03]
#  [-3.89124980e-03]
#  [ 1.34886063e-02]
#  [ 5.89726604e-03]
#  [-2.83084262e-04]
#  [-1.55646968e-02]
#  [-1.59313370e-03]
#  [ 3.04786435e-02]
#  [-8.68009830e-04]
#  [-1.19537466e-03]
#  [-1.80562496e-02]
#  [-1.45038694e-02]
#  [-1.86410725e-03]
#  [ 7.49363441e-03]
#  [-7.37671946e-03]
#  [ 1.41783073e-02]
#  [ 7.26322326e-03]
#  [-6.07111662e-03]
#  [-2.52374779e-02]
#  [-1.12002399e-02]
#  [-9.04832894e-03]
#  [ 1.03680070e-03]
#  [ 1.47585487e-02]
#  [-1.45571425e-02]
#  [ 5.85095227e-03]
#  [-4.05784403e-03]
#  [-1.20934704e-02]
#  [ 1.73106343e-02]]

# %%
fig, axes = plt.subplots(1, 2, sharex = True)  
axes[0].plot(mydata); axes[0].set_title('Order of Differencing: First')  
axes[1].set(ylim = (0, 1.2))  
plot_acf(mydata, ax = axes[1])  
plt.show()

# %%
# Looking at the autocorrelation graph, we can determine the number needed for q 
# Again, missing that blue box for significance 
#3 Otherwise, I would say that we have an order of 1 here

# %%
# Now building the ARIMA model 

import numpy as np, pandas as pd  
import statsmodels.api as sm

# %%
# importing data  
mydata = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)

# %%
# Creating ARIMA model 2
# change the () to whatever numbers we get from the results for p,d,q above 
mymodel = sm.tsa.arima.ARIMA(mydata.value, order = (1, 0, 1))  
modelfit = mymodel.fit()  

print(modelfit.summary())
# Out:
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  754
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                2062.924
# Date:                Thu, 06 Apr 2023   AIC                          -4117.847
# Time:                        09:44:29   BIC                          -4099.346
# Sample:                             0   HQIC                         -4110.720
#                                 - 754
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.405      0.686      -0.001       0.001
# ar.L1         -0.5698      0.058     -9.858      0.000      -0.683      -0.457
# ma.L1          0.3767      0.065      5.814      0.000       0.250       0.504
# sigma2         0.0002   6.39e-06     38.515      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              2881.88
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.58   Skew:                            -0.84
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# These are the results. We can alter the output by changing the AIC/ BIC if we have a close call. 

# Now we plot the residuals to ensure that there is no constant mean or varaince to worry about

# %%
import numpy as np, pandas as pd  
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# Plotting Residual Errors
myresiduals = pd.DataFrame(modelfit.resid)  
fig, ax = plt.subplots(1,2)  
myresiduals.plot(title = "Residuals", ax = ax[0])  
myresiduals.plot(kind = 'kde', title = 'Density', ax = ax[1])  
plt.show()

# %%
# Finally, graphing our predicted versus actual values for trend analysis

# %%
import numpy as np, pandas as pd  
from statsmodels.tsa.arima_model import ARIMA  
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_predict

# %%
plt.rcParams.update({'figure.figsize' : (9,3), 'figure.dpi' : 120})

# %%
# importing data  
mydata = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)

# %%
# The best fitting ARIMA model from before
# Change the () to whatever numbers we get from the results for p,d,q above 
mymodel = sm.tsa.arima.ARIMA(mydata.value, order = (1, 0, 1))  
modelfit = mymodel.fit()  

print(modelfit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  754
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                2062.924
# Date:                Thu, 06 Apr 2023   AIC                          -4117.847
# Time:                        09:44:51   BIC                          -4099.346
# Sample:                             0   HQIC                         -4110.720
#                                 - 754
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.405      0.686      -0.001       0.001
# ar.L1         -0.5698      0.058     -9.858      0.000      -0.683      -0.457
# ma.L1          0.3767      0.065      5.814      0.000       0.250       0.504
# sigma2         0.0002   6.39e-06     38.515      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              2881.88
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.58   Skew:                            -0.84
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Actual vs Fitted  

import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_predict
from statsmodels.tsa.arima.model import ARIMA

df = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)  
df.index = pd.date_range(start = '2020-01-01', end = '2022-01-01', freq='A')
res = ARIMA(dta, order=(1,0,1)).fit()
fig, ax = plt.subplots()
ax = dta.loc['2020-01-01':].plot(ax=ax)
plot_predict(res, '2020-01-01', '2022-01-01', ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 10
#       7 from statsmodels.tsa.arima.model import ARIMA
#       9 df = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)
# ---> 10 df.index = pd.date_range(start = '2020-01-01', end = '2022-01-01', freq='A')
#      11 res = ARIMA(dta, order=(1,0,1)).fit()
#      12 fig, ax = plt.subplots()
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/pandas/core/generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/pandas/core/generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/pandas/core/internals/managers.py:230, in BaseBlockManager.set_axis(self, axis, new_labels)
#     228 def set_axis(self, axis: int, new_labels: Index) -> None:
#     229     # Caller is responsible for ensuring we have an Index object.
# --> 230     self._validate_set_axis(axis, new_labels)
#     231     self.axes[axis] = new_labels
#
# File ~/opt/miniconda3/envs/econ/lib/python3.9/site-packages/pandas/core/internals/base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 754 elements, new values have 2 elements

# %%
# Working on making these into a matrix

# %%
# importing data  
mydata = pd.read_csv(os.path.join(DATA_DIR, 'returns.csv'), names = ['value'], header = 0)

# %%
# The best fitting ARIMA model from before
# Change the () to whatever numbers we get from the results for p,d,q above 
mymodel = sm.tsa.arima.ARIMA(mydata.value, order = (1, 0, 1))  
modelfit = mymodel.fit()  

print(modelfit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  754
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                2062.924
# Date:                Thu, 06 Apr 2023   AIC                          -4117.847
# Time:                        09:50:36   BIC                          -4099.346
# Sample:                             0   HQIC                         -4110.720
#                                 - 754
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.405      0.686      -0.001       0.001
# ar.L1         -0.5698      0.058     -9.858      0.000      -0.683      -0.457
# ma.L1          0.3767      0.065      5.814      0.000       0.250       0.504
# sigma2         0.0002   6.39e-06     38.515      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              2881.88
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.58   Skew:                            -0.84
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/tsagedouglas/opt/miniconda3/envs/econ/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
A = modelfit.model.ssm.transition[..., 0] 
print(A)
# Out:
# [[-0.56981815  1.        ]
#  [ 0.          0.        ]]

# %%
print(modelfit.params)
# Out:
# const     0.000217
# ar.L1    -0.569818
# ma.L1     0.376662
# sigma2    0.000246
# dtype: float64
